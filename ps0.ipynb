# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvpatwardhan/Atharv-Patwardhan-GIS-Coursework/blob/main/ps0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PS-0

# %% [markdown]
# Importing packages

# %%
# %%capture
# !pip install mapclassify
# !pip install geopandas

# %%
import geopandas as gpd
import seaborn as sns
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import files

import os
import zipfile
import requests

# %% [markdown]
# Importing the Dataset

# %%
url = "https://github.com/globalmaps/gmbg10/archive/refs/heads/master.zip"
zip_name = "gmbg10.zip"
folder_name = "gmbg10"

if not os.path.exists(folder_name):
    r = requests.get(url)
    with open(zip_name, "wb") as f:
        f.write(r.content)
    with zipfile.ZipFile(zip_name, "r") as z:
        z.extractall(".")
    os.rename("gmbg10-master", folder_name)

# %% [markdown]
# Plotting the map of Bulgaria

# %%
shapefile = os.path.join(folder_name, "polbnda.shp")
gdf = gpd.read_file(shapefile)

gdf.plot()
# Out:
# <Axes: >
